# %%
import keras
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import tweepy
import time
import random

import glob
import numpy as np
import pandas as pd
from nltk.tokenize import TweetTokenizer, casual_tokenize
from keras.models import load_model
import keras.preprocessing.text as kpt
from keras.preprocessing.text import text_to_word_sequence, one_hot, Tokenizer
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter
# Out:
# C:\Users\hello\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def sample(preds):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / 0.2
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

def generate_tweets(model, corpus, char_to_idx, idx_to_char, n_tweets=10): 
    
    tweets = []
    spaces_in_corpus = np.array([idx for idx in range(CORPUS_LENGTH) if text[idx] == ' '])
    for i in range(1, n_tweets + 1):
        begin = np.random.choice(spaces_in_corpus)
        tweet = u''
        sequence = text[begin:begin + MAX_SEQ_LENGTH]
        tweet += sequence
        for _ in range(100):
            x = np.zeros((1, MAX_SEQ_LENGTH, N_CHARS))
            for t, char in enumerate(sequence):
                x[0, t, char_to_index[char]] = 1.0

            preds = model.predict(x, verbose=0)[0]
            next_idx = sample(preds)
            next_char = index_to_char[next_idx]

            tweet += next_char
            sequence = sequence[1:] + next_char
        tweets.append(tweet)
    return tweets

# %%
path = 'data/'
os.chdir(path)
result = [i for i in glob.glob('*.csv')]

df_tweets = pd.DataFrame()
for file in result:
    temp = pd.read_csv(file, index_col=0)
    df_tweets = df_tweets.append(temp, ignore_index=True)
    
df_tweets['time'] = pd.to_datetime(df_tweets['time'])
df_tweets = df_tweets.sort_values('time').reset_index(drop=True)

df_noat = df_tweets.loc[df_tweets['Tweet text'].str.find('@') != 0].copy()
df_noat['text_lower'] = df_noat['Tweet text'].str.lower()
df_noat['text_lower'].iloc[0]
nw_words = [casual_tokenize(tweet, reduce_len=True, strip_handles=True) for tweet in df_noat['text_lower']]
crystal_corpus = [word for sub in nw_words for word in sub if 'http' not in word]
crystal_chars = [char for word in crystal_corpus for char in word]
chars_in_corpus = Counter()
text = []

for tweet in nw_words:
    for word in tweet:
        if 'http' not in word:

            text.append(word + ' ')
    text.append(' ` ')

text = "".join(text)

for char in text:
    chars_in_corpus.update(char)
    lexicon = list(chars_in_corpus.keys())
    char_to_index = {char: i for (i, char) in enumerate(lexicon)}
    index_to_char = {i: char for (i, char) in enumerate(lexicon)}

# %%
CORPUS_LENGTH = len(text)
MAX_SEQ_LENGTH = 140
SEQ_STEP = 2
N_SEQS = None
N_CHARS = len(lexicon)

# %%
model = load_model('botwan_v2.h5')

# %%
np.random.seed(78)

# %%
tweets = generate_tweets(model, text, char_to_index, index_to_char, n_tweets=69)
# Out:
# C:\Users\hello\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
tweets
# Out:
# [" in bark in the park matches  ` oh my god  ` :(  ` downloading twitter data is so ugh  ` i'm about fire sauce  ` the p in pvalue is silent  $7😨$7\U0001f923🌯$$🍔$😦$$🍔$75$75$$🍔$75$8😨$75🎶$😨🎶$757$757🌯$😦$🎶🌯$7\U0001f923🌯$7\U0001f923🌯$$🍔$7\U0001f9235$$🍔$😨$7\U0001f923🌯$$🍔$7\U0001f923🌯$75🎶$7😦$75$$🍔$🎶5$$",
#  ' believe in you so much !  ` i just found out that it\'s not called " kroger\'s " there\'s apparently no s .  ` not into stop 4 of this " tour $75$7😨$757$$🍔$75$😦🎶$7🌯$758$75$$🍔$75$75$$🍔$757$$🍔$😨🎶$$🍔$7🌯$$🍔$75$758$$🍔$75$$🍔$7\U0001f923🌯$$🍔$7🌯$7\U0001f923😨$$🍔$$🍔$75$',
#  ' - - even though that\'s what boot camps are promoting  ` authors suggest that bootcampers " conflate the intensity of the experience with it$7😨$$🍔$😨$757$7😨$$🍔$7😨$$🍔$7🌯$$🍔$🙌5$$🍔$8🌯$$🍔$758$757$😨$$🍔$757$75$758$7\U0001f923🌯$758$75🎶$757$7\U0001f923🌯8$7🌯$7😨7$😨$7😨$',
#  " finding a nice little home for people . seeing the process is so interesting  ` it's why i sort of think live coding was so strangely popul$75🎶$7😨7$857$😦$$🍔$7😨7$7😨f$$🍔$7\U0001f923🌯$$🍔$7🌯7$$🍔$7🌯$75$😦$75$😦$😨$75$$🍔$7😨🎶$75$75$75$757$7🌯$75$$🍔$😦$$🍔$7🌯$7😦"]

# %%
e_100 = '$7'

# %%
new_tweets = []
for subtweets in tweets:
    temp = subtweets.split('`')
    for tweet in temp:
        if e_100 in tweet:
            new_tweets.append(tweet[:tweet.find('$7')])
        else:
            new_tweets.append(tweet)

# %%
new_tweets
# Out:
# [' in bark in the park matches  ',
#  ' oh my god  ',
#  ' :(  ',
#  ' downloading twitter data is so ugh  ',
#  " i'm about fire sauce  ",
#  ' the p in pvalue is silent  ',
#  ' twitter is root for ya !  ',
#  ' looking to leave academia , anyone ?  ',
#  ' whoa !  ',
#  " it's #pugchat ! !  ",
#  ' interesting  ',
#  ' my tl is filled with brig',
#  ' only 16 % ( n = 48 ) reported being in a boot camp or something like it  ',
#  ' as for some of the measures ... they are somewhat narrow : resea',
#  '  ',
#  ' raisel making me shout louder than library voice at brewriver rn hot damn  ',
#  ' samwell out here calling for the cidatel to do more replica',
#  ' are the bee\'s knees ! " anyone ?  ',
#  ' grape soda tastes like carbonated melted grape otter pop  ',
#  ' tfw you run all cells but see something you',
#  ' back  ',
#  ' bunts everywhere . triples everywhere .  ',
#  ' 28 hits  ',
#  ' fierce pitching right here  ',
#  ' factory resetting my phone cc  ',
#  " that didn't fi$$🍔$$🍔",
#  ' . rts appreciated  ',
#  " whoa . i'm a twitch affiliate now ! who knew there were 50 twitch folks out there who were interested in data science 7$$🍔$😦🎶",
#  ' seafood commercials  ',
#  ' sox vs stockings mmm  ',
#  ' love salami  ',
#  '  ',
#  ' i got my phd in neuroscience and now i ’ m a data scientist for the cincin',
#  '  ',
#  ' baseball is rad  ',
#  ' nick wan standing by  ',
#  ' about to retire neuro jesus  ',
#  ' i thought butterbean and meat loaf were the same person and ca',
#  ' on this dataset - - also trying to plan for better streams in 2018 !  ',
#  ' whew ! 40 mins into overtime and learned that cheetahs , ducks , an$$🍔',
#  ' made me sad today ☹ ️  ',
#  ' mozzarella sticks  ',
#  ' salami for scooter !  ',
#  ' v jel of 100 % total eclipsers  ',
#  ' greetings , earthlings  ',
#  ' #whinging$$🍔',
#  " keep this on his feet if he's gonna have any chance  ",
#  ' barboza is about to eat another 50 fists here  ',
#  ' barboza needs to get off his back .$$🍔',
#  '  ',
#  ' i just found out layering bed sheets is a thing  ',
#  ' oh man  ',
#  ' stream starting now !  ',
#  " thanks for coming out y'all  ",
#  ' oh , interesting ! ',
#  ' conf papers , and conf abstracts . interesting that no sci comm work counts here ...  ',
#  ' socialization is also pretty narrow , as it is meas',
#  ' an option larger than " super " #burritochat  ',
#  " q2 what's your views on chipotle ? cheap and convenient ? not worth it ? tasty and deliciou$$🍔",
#  ' pinkies got bronze in funnel then 7th in long jump . hope they can medal next two  ',
#  ' dark . what a weird show .  ',
#  ' thanks for the card and $$🍔',
#  '  ',
#  ' lmao what tf is this  ',
#  ' my first science twitter interaction that i can vaguely remember was with . how both of us have evolved since th8$$🍔$😨$$🍔',
#  " y'all . thanks to for co hosting tonight , see y'all thursday !  ",
#  ' yeah wtf was that ! ! !  ',
#  ' also one follower away from being able to get8',
#  ' have dobby anymore all i have is baseball pics like this  ',
#  " here's a dobby pic from the archives  ",
#  " here's some elote . it was really good ",
#  ' :(  ',
#  " watching naked on netflix . it says there's some time travel component . it also says it's a rom com . i'm a sucker for time travel t7",
#  ' ',
#  ' watch out !  ',
#  ' the mobile site is truly a test of patience  ',
#  ' #pugchat is the best  ',
#  ' omfg yes  ',
#  ' dodgers on watch  ',
#  ' 💅  ',
#  ' man . 9 hitles$😨$$🍔',
#  ' tap out song  ',
#  ' watching the defiant ones  ',
#  ' yay new compy soon  ',
#  ' okay chromecast 4k is rad  ',
#  ' the defiant ones first episode , when dre i',
#  ' obviously .  ',
#  " the next time i'm at usu , does someone want to do a self-guided napoleon dynamite tour of preston with me ?  ",
#  ' my myspace t',
#  ' need to do laundry and groceries . and eat . and everything .  ',
#  ' jimmy g is looking great  ',
#  " alright folks who come into my streams , it's $$🍔",
#  " the best post season , that's for sure .  ",
#  ' first viz using seaborn.tsplot ( ) felt rad , i think i ate a victory burrito over it . #codene',
#  ' !  ',
#  ' ... chicken and waffles though  ',
#  ' pacquiao  ',
#  ' midnight live espn is pretty cool tho  ',
#  ' before i went to grad school , someone asked me',
#  '  ',
#  ' even with that pop , manny has all these head taps this round ...  ',
#  ' horn 56 pac 58 horn had good pacing this entire round . although if',
#  ' them once you walk into the convention center .  ',
#  ' stream up with me and - - hoping to see some closure to the branches of sci project toni$8😨7$$🍔',
#  ' and then two outbreaks happen on it , kinda .  ',
#  " i've never heard this song before  ",
#  " for reference , here's where coffey park is and here'$😦$857",
#  ' dee doo  ',
#  " 🎓 saint mary's bs / utah state phd 💼 data scientist for the cincinnati reds 🍔 🍔 🍔 #ypsportschat  ",
#  ' unsure , but i do enjoy watch$$🍔',
#  ' to have this level of grudge  ',
#  ' in boston for the weekend . sup ?  ',
#  ' gonna be at the meet up in cambridge tomorrow night . come say hi !  ',
#  '',
#  ' next week  ',
#  ' what a comeback  ',
#  ' installing tf gpu on my desktop and some how messed everything up  ',
#  ' i feel like 🚮  ',
#  " it's me but jet lagge",
#  '  ',
#  '  ',
#  ' i got my phd in neuroscience and now i ’ m a data scientist for the cincinnati reds #postphdlife  ',
#  ' ayyy  ',
#  ' this bar plays tegan and 8',
#  '  ',
#  " there's an academia metaphor in here somewhere  ",
#  ' oh ?  ',
#  ' 💅  ',
#  ' aw damn  ',
#  " on the plus side , i did get to see nick and juliette's house $$🍔",
#  ' ',
#  ' nah  ',
#  ' taco hat  ',
#  ' i done goofed  ',
#  " overwatch id's plz  ",
#  " it's fine  ",
#  ' might need this  ',
#  " that synth on halsey's bad at love sounds like 8",
#  " parent's house basically is . coffey park pic from the chp .  ",
#  ' when they cut up that call , remember that it started with " they may have ',
#  ' and python scripts ! thanks yall ! stream up in 30 mins . come in and say hey !  ',
#  ' stream up ! ! jasmine returns ! nlp basics tonight  ',
#  ' my$$🍔',
#  '  ',
#  ' if you have interesting research on heuristics or theory of mind and have a poster at #sfn17 let me know  ',
#  ' obviously , anything on stra🎶$$🍔',
#  ' get suspicious over emails from hotmail dot com  ',
#  " there's a stream tonight at 8p m est yall . we're still working through twitter data tre$85$$🍔",
#  ' i went to grad school , someone asked me if i\'m " going to save freddie roach ? " has parkinson\'s . i didn\'t , but great people are trying ',
#  " couldn't do anything against the fence . we know her kickboxing , holly in the clinch tho ?  ",
#  " holm respecting cyborg's shooting ability he",
#  ' lmao  ',
#  ' shout out to that do who just shouted out bacon as loud as possible  ',
#  " this is way crazier of a story now that i'm not 10  ",
#  ' does t$-5$😦',
#  '  ',
#  ' huh . that fairy scene . what .  ',
#  ' this orc is named nick . i can relate . i am names nick .  ',
#  ' i like how orc music is just metal . how$😦$$🍔',
#  ' insecure ! ! !  ',
#  ' oh my god we get all the due north clips rn ! ! !  ',
#  ' due north season finale was also amazing lmao  ',
#  ' heated gaming momen',
#  ' #burritochat  ',
#  " a1 in petaluma , ca there's a spot called mi pueblo that does my fav wet burrito #burritochat  ",
#  ' feel free to introduce you',
#  '  ',
#  ' in nyc next weekend  ',
#  ' dc vs oakland tonight  ',
#  ' new one mississippi is so feels  ',
#  ' the tree outside is two colors  ',
#  ' you might be cool ,',
#  ' ',
#  ' might regret this , but dms are open for qs  ',
#  ' rt for the people who are long distance - - remote work is available !  ',
#  " yo isn't verifie$$🍔",
#  ' whatever was on my hand ( i think either toothpaste or spicy stuff ) is now in my eye and i am definitely awake good morning .  ',
#  ' i hate yo$$🍔',
#  " hey sorry if i haven't had the chance to talk to you . i really am trying to meet everyone . find me tomorrow , dms open  ",
#  ' yo the internet$85$$🍔',
#  " page nyt article . that opened my eyes to sports analytics as a career path . a few years later , here i am . can't thank you enough !  ",
#  ' d$😨🎶$$🍔',
#  ' tho  ',
#  ' what would wick nan do  ',
#  ' apply early to jobs . i applied to pds the summer before i graduated , with target start being 12 months f',
#  ' ama  ',
#  ' triple berry . from wish bone in petaluma  ',
#  ' nah  ',
#  ' taco hat  ',
#  ' i done goofed  ',
#  " overwatch id's plz  ",
#  " it's fine  ",
#  ' might need this ',
#  ' the last 24 hrs , kevin durant outed himself . pseud life is tuff yall  ',
#  ' the lunchables today were great btw  ',
#  ' oh my lord , randy moss yo$$🍔$😦8',
#  " horn 56 pac 58 horn had good pacing this entire round . although if you're a stats guy , that's more shots for pac this rd too ...  ",
#  ' appar',
#  " the reds as a data scientist . i went to st mary's in ca . i just watched scheb hit a grand slam ! #ypsportschat  ",
#  ' the ss costs less than ',
#  ' idk where fake nick wan is , sorry yall  ',
#  '  ',
#  ' no one is doing any research with donkeys at sfn so i can\'t use my " more like society for bu',
#  ' .  ',
#  ' anyone have a corpus for psychology terms ?  ',
#  ' was really hoping roankoke way distillery was real  ',
#  ' was i not suppose to laugh at thi$😨8$😦🎶',
#  ' at confs ! #ypsportschat  ',
#  " wow . this is the most accurate quiz i've ever taken .  ",
#  ' if it is < 50 % midwest ... what is it ?  ',
#  ' mt , wy ,$😦🎶',
#  ' not long ago , we were eating super nachos and in the lab at 2am . now we are in different labs with different nachos .  ',
#  ' basically going 🎶',
#  '  ',
#  ' good luck to tomorrow ! neuro twitter is root for ya !  ',
#  ' looking to leave academia , anyone ?  ',
#  ' whoa !  ',
#  " it's #pugchat ! !  ",
#  ' interes$$🍔$😦$$🍔$😨🎶$$🍔',
#  ' code random tweepy stuff ?  ',
#  ' so like two people are interested lol  ',
#  " okay let's do it my nose is bleeding tho  ",
#  " i'm live with a noseblee",
#  ' ball is v compelling tonight  ',
#  ' this is great for new tattoos  ',
#  ' , , , idk what alex did with his hands there  ',
#  ' how tf did michelle tafoya8',
#  ' my interest in tennis . took me 4 yrs on twitter but i do like watching it now  ',
#  ' crippling self doubt tho  ',
#  ' what would wick nan do  ',
#  ' app$$🍔',
#  " horn 56 pac 58 horn had good pacing this entire round . although if you're a stats guy , that's more shots for pac this rd too ...  ",
#  ' appar$$🍔$-5$$🍔$😨$8😨7$$🍔',
#  ' pic from the archives  ',
#  " here's some elote . it was really good .  ",
#  ' wtf i gained 3 followers  ',
#  " tqdm is pretty rad if you're neurotic abou$$🍔$-57🌯",
#  ' 😩  ',
#  ' are there data viz throw pillows ?  ',
#  " i ... actually didn't see that twist coming . watching glow .  ",
#  " watching the anarchist's cookbo",
#  ' believe in you so much !  ',
#  ' i just found out that it\'s not called " kroger\'s " there\'s apparently no s .  ',
#  ' not into stop 4 of this " tour ',
#  " - - even though that's what boot camps are promoting  ",
#  ' authors suggest that bootcampers " conflate the intensity of the experience with it',
#  ' finding a nice little home for people . seeing the process is so interesting  ',
#  " it's why i sort of think live coding was so strangely popul"]

# %% [markdown]
# # To do:
# * Automated tweets (on a timer?)
# * reply/interactive tweeting
# * go back and see why it's training on weird stuff
# * mine more tweets from other "nick wan esque" tweeters (???)
#
# load from:
# ../twitch/botwan/data/botwan_v2.h5

# %%
access = pd.read_csv('access.csv', header=None, index_col=0) 
auth = tweepy.OAuthHandler(access.loc[0].values[0], access.loc[1].values[0])
auth.set_access_token(access.loc[2].values[0], access.loc[3].values[0])
api = tweepy.API(auth)

# %%
for DFJAKLFDS in range(90):
    timeline = api.mentions_timeline(count=10)
    botwan_follows = api.friends('bot__wan')
    follow_list = [followee.screen_name for followee in botwan_follows]

    most_recent_people = list(set([tweet.author.screen_name for tweet in timeline]))

    reply_list = []
    for person in most_recent_people:
        if person in follow_list:
            reply_list.append(person)

    for reply_tweet in timeline:
        if reply_tweet.author.screen_name in reply_list:
            api.update_status(status='@' + reply_tweet.author.screen_name + ' ' + new_tweets[random.choice(range(len(new_tweets)))], in_reply_to_status_id=reply_tweet.id)
            reply_list.remove(reply_tweet.author.screen_name)
    time.sleep(28800)
